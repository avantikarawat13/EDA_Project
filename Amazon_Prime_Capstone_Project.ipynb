# %% [markdown]
# # **Project Name**    - Amazon Prime TV Shows and Movies

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual (Avantika Rawat)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Amazon Prime is a subscription-based service offered by Amazon that provides members with a wide array of benefits across shopping, entertainment, and more. Launched in 2005, Amazon Prime has evolved from a straightforward shipping program into a comprehensive digital ecosystem that integrates retail, streaming, gaming, reading, and exclusive services. As of 2025, it has over 200 million subscribers globally and continues to be a key driver of Amazon’s customer loyalty and revenue growth.
#
# **Amazon Prime Video: A Streaming Giant in Your Living Room**
#
# Amazon Prime Video is one of the major players in the world of online streaming, offering a vast and diverse library of movies, TV shows, documentaries, and original content. It’s part of the broader Amazon Prime membership, which also includes perks like free shipping, music streaming, and e-book lending. But even if you look at Prime Video on its own, it stands tall as a full-fledged entertainment hub for millions around the world.
#
# At its core, Prime Video is Amazon’s answer to the growing demand for on-demand entertainment. You can watch what you want, when you want, on virtually any device—smart TVs, phones, tablets, game consoles, or even just your web browser. Whether you're in the mood for a quick comedy series, a thrilling blockbuster, or a niche indie film, chances are you’ll find something to suit your taste.
#
# One of the platform’s biggest strengths is its variety. Prime Video doesn’t lean too heavily on one genre or one type of content. Instead, it spreads its wings across everything from big-budget Hollywood movies and international films to critically acclaimed TV dramas and kids’ shows. There’s something for everyone—families, film buffs, casual viewers, and binge-watchers alike.
#
# What really sets Prime Video apart, though, is its **original content**, branded as “Amazon Originals.” These are shows and movies produced or exclusively distributed by Amazon Studios. Some of them, like *The Marvelous Mrs. Maisel*, *Jack Ryan*, *The Boys*, and *Reacher*, have become household names. Amazon has invested heavily in these productions, not just for quantity but for quality. Many Originals have won Emmys, Golden Globes, and other major awards, proving that the platform isn’t just about streaming other people’s content—it’s a serious creative force of its own.
#
# In addition to its originals and standard library, Prime Video also allows users to rent or buy movies that aren’t included in the subscription. This is handy if you’re looking for the latest theatrical releases or older classics that might not be included in the free catalog. You can also subscribe to “Channels” through Prime Video—add-on services like HBO, Showtime, Starz, and more—essentially customizing your streaming bundle within one app.
#
# The platform also supports **multiple languages and subtitles**, making it accessible to a global audience. In recent years, Amazon has made a strong push into regional and international content, especially in countries like India. You'll find popular Hindi, Tamil, Telugu, and Malayalam series, as well as Korean dramas, European thrillers, and Latin American telenovelas. This multilingual, multicultural approach adds a lot of flavor to the service.
#
# Another plus? The **user interface** is pretty intuitive. It’s easy to search, browse by category, check out recommendations, or pick up where you left off. Prime Video’s “X-Ray” feature is especially popular—it shows actor info, trivia, and music used in a scene while you’re watching, making it a more interactive viewing experience.
#
# Of course, no service is perfect. One criticism Prime Video sometimes gets is that its interface mixes included content with paid content, which can be confusing. You might click on a title thinking it’s part of your subscription, only to find out it’s available only for rent or purchase. Some users also feel that while the library is broad, it lacks the same level of curation or standout exclusives that platforms like Netflix or Disney+ might offer.
#
# Still, Prime Video’s value proposition is strong. For many people, it’s bundled with an Amazon Prime membership they already have, which makes it feel like a bonus. But even as a standalone service, it's worth considering. With a growing investment in original content, a wide global footprint, and access to some of the biggest new movies, it continues to hold its place in the crowded streaming market.
#
# In short, **Amazon Prime Video is a flexible, content-rich streaming service** that caters to all kinds of viewers. Whether you're into big-budget series, indie films, global cinema, or family-friendly shows, Prime Video has something to keep you entertained—whenever and wherever you want.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/avantikarawat13/EDA_Project

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Problem Statement
#
# This dataset was created to analyze all shows available on Amazon Prime Video, allowing us to extract valuable insights such as:
#
# Content Diversity: What genres and categories dominate the platform?
# Regional Availability: How does content distribution vary across different regions?
# Trends Over Time: How has Amazon Prime’s content library evolved?
# IMDb Ratings & Popularity: What are the highest-rated or most popular shows on the platform?
# By analyzing this dataset, businesses, content creators, and data analysts can uncover key trends that influence subscription growth, user engagement, and content investment strategies in the streaming industry.
#
# Main Libraries to be used:
#
# Pandas for data manipulation, aggregation
# Matplotlib and Seaborn for visualization and behavior with respect to the target variable. Use at least 5 different visualizations.
# NumPy for computationally efficient operations
#
#
#
#
# Project Architecture:

# %% [markdown]
# ![Chat_GPT_Image_May_28_2025_12_45_23_PM_51a69d5215.png](data:image/png;base64,...)

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Business Context
#
# In today's competitive streaming industry, platforms like Amazon Prime Video are constantly expanding their content libraries to cater to diverse audiences. With a growing number of shows and movies available on the platform, data-driven insights play a crucial role in understanding trends, audience preferences, and content strategy.
#
# This data set was created to list all shows available on Amazon Prime streaming, and analyze the data to find interesting facts. This dataset has data available in the United States.
#
# This dataset has 2 csv files and it is a mix of categorical and numeric values.
#
# Dataset Description
#
# This data set was created to list all shows available on Amazon Prime streaming, and analyze the data to find interesting facts. This dataset has data available in the United States.
#
# This dataset has two files containing the titles (titles.csv) and the cast (credits.csv) for the title.
#
# This dataset contains +9k unique titles on Amazon Prime with 15 columns containing their information, including:
#
# id: The title ID on JustWatch.
# title: The name of the title.
# show_type: TV show or movie.
# description: A brief description.
# release_year: The release year.
# age_certification: The age certification.
# runtime: The length of the episode (SHOW) or movie.
# genres: A list of genres.
# production_countries: A list of countries that produced the title.
# seasons: Number of seasons if it's a SHOW.
# imdb_id: The title ID on IMDB.
# imdb_score: Score on IMDB.
# imdb_votes: Votes on IMDB.
# tmdb_popularity: Popularity on TMDB.
# tmdb_score: Score on TMDB.
# And over +124k credits of actors and directors on Amazon Prime titles with 5 columns containing their information:
#
# person_ID: The person ID on JustWatch.
# id: The title ID on JustWatch.
# name: The actor or director's name.
# character_name: The character name.
# role: ACTOR or DIRECTOR.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
titles_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Module 2/Mod 2 data/titles.csv')
credits_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Module 2/Mod 2 data/credits.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
titles_data.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
credits_data.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
titles_data.shape
# Out:
# (9871, 15)

# %%
credits_data.shape
# Out:
# (124235, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
titles_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %%
credits_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
titles_data.duplicated().sum()
# Out:
# np.int64(3)

# %%
credits_data.duplicated().sum()
# Out:
# np.int64(56)

# %% [markdown]
# Before we proceed further, we will merge the titles_data and credits_data to analyse it in a better way.
# 'id' is the common column/ key with respect to the give data

# %%
amazon_p = pd.merge(titles_data, credits_data,on = 'id', how = 'inner')

# %%
amazon_p.shape
# Out:
# (124347, 19)

# %%
amazon_p.head()
# Out:
#         id              title   type  \
# 0  ts20945  The Three Stooges   SHOW
# 1  ts20945  The Three Stooges   SHOW
# 2  ts20945  The Three Stooges   SHOW
# 3  tm19248        The General  MOVIE
# 4  tm19248        The General  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
# 2  The Three Stooges were an American vaudeville ...          1934
# 3  During America’s Civil War, Union spies steal ...          1926
# 4  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
# 2             TV-PG       19
# 3               NaN       78
# 4               NaN       78
#
#                                               genres production_countries  \
# ...

# %%
amazon_p.tail()
# Out:
#                id     title   type  \
# 124342  tm1054116  Baikunth  MOVIE
# 124343  tm1054116  Baikunth  MOVIE
# 124344  tm1054116  Baikunth  MOVIE
# 124345  tm1054116  Baikunth  MOVIE
# 124346  tm1054116  Baikunth  MOVIE
#
#                                               description  release_year  \
# 124342  This story is about prevalent caste problem, e...          2021
# 124343  This story is about prevalent caste problem, e...          2021
# 124344  This story is about prevalent caste problem, e...          2021
# 124345  This story is about prevalent caste problem, e...          2021
# 124346  This story is about prevalent caste problem, e...          2021
#
#        age_certification  runtime               genres production_countries  \
# 124342               NaN       72  ['family', 'drama']                   []
# 124343               NaN       72  ['family', 'drama']                   []
# 124344               NaN       72  ['family', 'drama']                   []
# ...

# %%
amazon_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124347 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    124347 non-null  object
#  1   title                 124347 non-null  object
#  2   type                  124347 non-null  object
#  3   description           124256 non-null  object
#  4   release_year          124347 non-null  int64
#  5   age_certification     56707 non-null   object
#  6   runtime               124347 non-null  int64
#  7   genres                124347 non-null  object
#  8   production_countries  124347 non-null  object
#  9   seasons               8153 non-null    float64
#  10  imdb_id               119044 non-null  object
#  11  imdb_score            118296 non-null  float64
#  12  imdb_votes            118272 non-null  float64
#  13  tmdb_popularity       124332 non-null  float64
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %% [markdown]
# Transforming the null Columns: Filling values into them as per the requirement.
#
# 1.  Checking for the duplicated and null values.
# 2.  Removing duplicates from the merged dataset.
# 3. Creating a new column that will enable the credit value visible for each character and eases the visualization for the character column.
# 4. Creating a new column besides the original one, for ease of access.

# %%
# Missing Values/Null Values Count
amazon_p.isnull().sum()
# Out:
# id                           0
# title                        0
# type                         0
# description                 91
# release_year                 0
# age_certification        67640
# runtime                      0
# genres                       0
# production_countries         0
# seasons                 116194
# imdb_id                   5303
# imdb_score                6051
# imdb_votes                6075
# tmdb_popularity             15
# tmdb_score               10265
# person_id                    0
# name                         0
# character                16307
# role                         0
# dtype: int64

# %%
amazon_p.duplicated().sum()
# Out:
# np.int64(168)

# %%
amazon_p.drop_duplicates(inplace = True)

# %%
amazon_p.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Fill null values by constant, mean,median or mode as per the requirement.

# %%
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
amazon_p.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score', 'person_id', 'name', 'character', 'role'],
#       dtype='object')

# %%
amazon_p['age_certification'].isnull().sum()
# Out:
# np.int64(67472)

# %%
amazon_p['age_certification'].fillna('Not Mentioned', inplace = True)

# %%
amazon_p['seasons'].fillna(0, inplace = True)

# %%
amazon_p['seasons'] = amazon_p['seasons'].astype('int')

# %%
amazon_p['description'].fillna('Not Mentioned', inplace = True)

# %%
amazon_p['imdb_id'].fillna('Blank', inplace = True)

# %%
amazon_p['imdb_score'].fillna(amazon_p['imdb_score'].mean(), inplace = True)

# %%
amazon_p['imdb_votes'].fillna(amazon_p['imdb_votes'].median(), inplace = True) # Median because not affected by outliers

# %%
amazon_p['tmdb_score'].fillna(amazon_p['tmdb_score'].mean(), inplace = True)

# %%
amazon_p['character'].fillna('Not Mentioned', inplace = True)

# %%
amazon_p['tmdb_popularity'].fillna(amazon_p['tmdb_popularity'].median(), inplace = True)

# %%
amazon_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124179 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    124179 non-null  object
#  1   title                 124179 non-null  object
#  2   type                  124179 non-null  object
#  3   description           124179 non-null  object
#  4   release_year          124179 non-null  int64
#  5   age_certification     124179 non-null  object
#  6   runtime               124179 non-null  int64
#  7   genres                124179 non-null  object
#  8   production_countries  124179 non-null  object
#  9   seasons               124179 non-null  int64
#  10  imdb_id               124179 non-null  object
#  11  imdb_score            124179 non-null  float64
#  12  imdb_votes            124179 non-null  float64
#  13  tmdb_popularity       124179 non-null  float64
# ...

# %%
amazon_p.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# person_id               0
# name                    0
# character               0
# role                    0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ## Amazon Prime Video Dataset
#
# The Amazon Prime Video dataset is composed of two key CSV files: `titles.csv` and `credits.csv`. The `titles.csv` file contains metadata about approximately 9,871 movies and shows, including their titles, release years, genres, runtimes, descriptions, age certifications, IMDb and TMDb ratings, and popularity metrics. It also includes data on the number of seasons for TV shows and the production countries. The `credits.csv` file, with over 124,000 entries, contains information on cast and crew—linking people to titles with roles (e.g., actor, director) and characters played.
#
# This dataset offers a rich opportunity to explore the content catalog of Amazon Prime Video, examining the performance, genre distribution, demographics, and market alignment of its video content. For instance, it captures how content varies by genre, production region, or audience rating, and includes critical popularity indicators such as IMDb scores, vote counts, and TMDb popularity ratings.
#
# ### Key Learnings from the Dataset
#
# * **Content Composition**: We can understand the split between movies and TV shows, dominant genres (like drama, comedy, thriller), and distribution of content across release years.
# * **Audience Targeting**: By examining age certifications and genres, we can infer which demographics are being targeted, and which segments are underserved.
# * **Performance Indicators**: IMDb and TMDb scores/votes can be used to assess the success of titles. Correlation analysis between genres, scores, and popularity can reveal what content resonates most.
# * **Temporal Trends**: With data going back decades, we can analyze how content strategy has evolved, including shifts in genre focus or audience preferences.
# * **People Analytics**: From the `credits.csv`, we can track which actors or directors frequently contribute to high-performing content.
#
# ### Business Insights and Applications
#
# 1. **Content Strategy Optimization**:
#
#    * Identify high-performing genres or regions (e.g., US-produced thrillers with high IMDb ratings).
#    * Spot underrepresented but high-potential areas (e.g., foreign dramas with cult followings).
#
# 2. **Personalized Recommendations**:
#
#    * Use historical rating trends to improve algorithms that suggest content to users based on genre and viewer profile.
#
# 3. **Talent Acquisition and Retention**:
#
#    * Analyze which actors or directors consistently deliver high-rated content to inform casting and contracting decisions.
#
# 4. **Market Expansion and Localization**:
#
#    * Study country-based production to evaluate opportunities for regional content development that aligns with global viewer preferences.
#
# 5. **Customer Segmentation**:
#
#    * Use age certification and genre preferences to segment audiences more precisely and guide targeted marketing campaigns.
#
#
# In summary, the dataset is a rich resource for evaluating content performance, understanding viewer preferences, and shaping business strategies in the streaming industry. Insights derived from it are not just academic—they translate into actionable strategies for growth, retention, and competitive positioning.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
amazon_p.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score', 'person_id', 'name', 'character', 'role'],
#       dtype='object')

# %%
# Dataset Describe
amazon_p.describe()
# Out:
#         release_year        runtime        seasons     imdb_score  \
# count  124179.000000  124179.000000  124179.000000  124179.000000
# mean     1996.307186      95.577706       0.153488       5.968327
# std        27.752141      30.166205       0.989185       1.211617
# min      1912.000000       1.000000       0.000000       1.100000
# 25%      1983.000000      83.000000       0.000000       5.300000
# 50%      2009.000000      93.000000       0.000000       6.000000
# 75%      2017.000000     109.000000       0.000000       6.800000
# max      2022.000000     540.000000      49.000000       9.900000
#
#          imdb_votes  tmdb_popularity     tmdb_score     person_id
# count  1.241790e+05    124179.000000  124179.000000  1.241790e+05
# mean   2.219857e+04        10.177173       5.991464  4.065843e+05
# std    8.639974e+04        40.762908       1.265955  5.617204e+05
# min    5.000000e+00         0.000011       0.800000  1.000000e+00
# ...

# %%
amazon_p.describe(include = 'object')
# Out:
#               id             title    type  \
# count     124179            124179  124179
# unique      8861              8748       2
# top     tm458582  Coming 2 America   MOVIE
# freq         137               137  116026
#
#                                               description age_certification  \
# count                                              124179            124179
# unique                                               8834                12
# top     Prince Akeem Joffer is set to become King of Z...     Not Mentioned
# freq                                                  137             67472
#
#            genres production_countries imdb_id                  name  \
# count      124179               124179  124179                124179
# unique       1965                  482    8268                 79758
# top     ['drama']               ['US']   Blank  George 'Gabby' Hayes
# freq         9853                69217    5303                    49
#
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
#  ### 📄 Dataset 1: `titles.csv` (Content Metadata)
#
# | Column Name             | Data Type | Description |
# |-------------------------|-----------|-------------|
# | `id`                    | object    | Unique identifier for each title. Can be used to join with `credits.csv`. |
# | `title`                 | object    | Name of the movie or TV show. |
# | `type`                  | object    | Either `MOVIE` or `SHOW`. |
# | `description`           | object    | Brief summary or synopsis of the title. |
# | `release_year`          | int64     | Year when the title was released. |
# | `age_certification`     | object    | Viewer age rating (e.g., PG-13, R, TV-MA). Useful for content targeting. |
# | `runtime`               | int64     | Duration in minutes for movies or episodes. |
# | `genres`                | object    | List of genres associated with the title (stored as stringified list). |
# | `production_countries`  | object    | List of country codes where the title was produced. |
# | `seasons`               | float64   | Number of seasons (only applicable to shows). |
# | `imdb_id`               | object    | IMDb identifier for external referencing. |
# | `imdb_score`            | float64   | IMDb rating score (0-10). |
# | `imdb_votes`            | float64   | Number of votes on IMDb. Reflects popularity. |
# | `tmdb_popularity`       | float64   | Popularity metric from TMDb. |
# | `tmdb_score`            | float64   | TMDb rating score (0-10). |
#
#
#
#  ### 📄 Dataset 2: `credits.csv` (Cast and Crew Info)
#
# | Column Name  | Data Type | Description |
# |--------------|-----------|-------------|
# | `person_id`  | int64     | Unique identifier for the person (actor/director). |
# | `id`         | object    | Foreign key matching `titles.id`. |
# | `name`       | object    | Full name of the cast/crew member. |
# | `character`  | object    | Character name played (if applicable). Mostly for actors. |
# | `role`       | object    | Role in the production: e.g., `ACTOR`, `DIRECTOR`. |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
amazon_p.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score', 'person_id', 'name', 'character', 'role'],
#       dtype='object')

# %%
# Check Unique Values for each variable.

# %%
amazon_p['title'].unique()
# Out:
# array(['The Three Stooges', 'The General', 'The Best Years of Our Lives',
#        ..., 'Jay Nog: Something from Nothing', 'Chasing', 'Baikunth'],
#       dtype=object)

# %%
amazon_p['type'].unique()
# Out:
# array(['SHOW', 'MOVIE'], dtype=object)

# %%
amazon_p['release_year'].unique()
# Out:
# array([1934, 1926, 1946, 1940, 1950, 1939, 1945, 1936, 1916, 1925, 1938,
#        1932, 1944, 1928, 1941, 1937, 1942, 1924, 1947, 1943, 1931, 1933,
#        1923, 1949, 1948, 1919, 1920, 1921, 1922, 1927, 1935, 1915, 1918,
#        1929, 1914, 1930, 1912, 1917, 1974, 1951, 1976, 1980, 1968, 1975,
#        1960, 1971, 1978, 1979, 1977, 1973, 1955, 1972, 1963, 1965, 1957,
#        1952, 1966, 1953, 1961, 1962, 1964, 1958, 1970, 1969, 1959, 1956,
#        1954, 1967, 1989, 1984, 1988, 1981, 1986, 1983, 1990, 1987, 1985,
#        1982, 1992, 1999, 2000, 1997, 1993, 1996, 1995, 1998, 1994, 1991,
#        2004, 2010, 2005, 2001, 2006, 2009, 2008, 2002, 2003, 2007, 2012,
#        2011, 2013, 2014, 2015, 2016, 2018, 2017, 2020, 2019, 2022, 2021])

# %%
amazon_p['age_certification'].unique()
# Out:
# array(['TV-PG', 'Not Mentioned', 'PG', 'G', 'PG-13', 'R', 'TV-G', 'TV-Y',
#        'TV-14', 'NC-17', 'TV-Y7', 'TV-MA'], dtype=object)

# %%
amazon_p['runtime'].unique()
# Out:
# array([ 19,  78, 171,  92,  94,  96, 130,  66,  95,  57, 197, 101,  63,
#        104,  99,  70, 115, 106, 100, 128,  89, 112, 103, 149,  83,  88,
#        109,  90,  93,  76, 105, 102, 120, 122, 116,  67,  80, 123, 134,
#         69, 113,  86,  53, 110,  61,  77, 118, 119,  79,  75, 150,  58,
#        133,  45, 108,  38, 111, 258,  68,  30,  73,  98,  72,  32,  84,
#         64,  81,  87,  74, 145,  60, 132,  65, 140,  71,  59,  85,  91,
#        228,  42,  56,  52,  48,  47,  62, 117,  20,  55,  54,  82, 143,
#         41, 158, 138,  97, 121,  50,  22,  51, 153,  40, 170, 328,  36,
#        129, 125, 237,  29, 107, 163, 260, 124,  23,  24,  26,  25, 246,
#        157, 165, 139, 208,  13, 137, 127, 126, 189, 136, 114,  28, 147,
#        159,  46, 176, 181, 161, 177, 148, 152, 180, 160, 178, 141, 168,
#        151, 155, 175,  27, 131, 154, 146, 182, 173, 156,  21,  10,   9,
#         43, 251, 174,  15, 172, 179, 142, 162, 166, 135, 144, 194,  44,
# ...

# %%
amazon_p['genres'].unique()
# Out:
# array(["['comedy', 'family', 'animation', 'action', 'fantasy', 'horror']",
#        "['action', 'drama', 'war', 'western', 'comedy', 'european']",
#        "['romance', 'war', 'drama']", ...,
#        "['drama', 'romance', 'comedy', 'history']",
#        "['thriller', 'western', 'comedy']",
#        "['comedy', 'action', 'family']"], dtype=object)

# %%
amazon_p['production_countries'].unique()
# Out:
# array(["['US']", "['GB']", "['MX', 'US']", "['GB', 'CA']", "['DE', 'US']",
#        "['SU']", "['IN']", "['CA', 'US']", "['MX']", "['XX']", '[]',
#        "['US', 'IT']", "['JP']", "['IT', 'FR']", "['HK']",
#        "['FR', 'DE', 'IT']", "['ES', 'IT']", "['GB', 'US']",
#        "['IL', 'US']", "['US', 'FR', 'IT']", "['IT']",
#        "['IT', 'GB', 'US']", "['GB', 'US', 'IT', 'MX', 'ES']",
#        "['AU', 'US']", "['CH', 'GB']", "['CA', 'FR']", "['US', 'IE']",
#        "['GB', 'IT']", "['IT', 'US']", "['FR']", "['GR', 'US']", "['DE']",
#        "['HK', 'US', 'CN']", "['US', 'ES']", "['PH', 'US']",
#        "['NL', 'US']", "['FR', 'US']", "['IT', 'YU']",
#        "['FR', 'DE', 'CH', 'CI']", "['PR', 'US']", "['US', 'PH']",
#        "['YU', 'US']", "['IT', 'MX']", "['IT', 'ES', 'DE', 'LI']",
#        "['US', 'CA']", "['US', 'GB']", "['US', 'DE']",
#        "['US', 'IT', 'FR']", "['CA']", "['FR', 'GB']", "['JP', 'KR']",
# ...

# %%
amazon_p['seasons'].unique()
# Out:
# array([26,  0, 18,  9, 31,  6, 12, 49,  3, 11, 22,  8,  2,  4,  1,  7, 16,
#        24, 35,  5, 34, 13, 15, 42, 10, 25, 14, 19, 21, 28, 17])

# %%
amazon_p['imdb_id'].unique()
# Out:
# array(['tt0850645', 'tt0017925', 'tt0036868', ..., 'tt7672388',
#        'tt15041600', 'tt14331982'], dtype=object)

# %%
amazon_p['imdb_score'].unique()
# Out:
# array([8.6       , 8.2       , 8.1       , 7.8       , 7.9       ,
#        7.3       , 8.        , 4.        , 7.7       , 7.5       ,
#        3.7       , 7.1       , 7.6       , 7.4       , 7.        ,
#        6.6       , 6.3       , 7.2       , 6.7       , 6.5       ,
#        6.9       , 5.96832673, 6.2       , 6.        , 6.4       ,
#        5.3       , 5.9       , 5.1       , 5.8       , 6.8       ,
#        5.5       , 4.9       , 5.7       , 5.        , 5.2       ,
#        3.5       , 3.4       , 8.3       , 6.1       , 4.8       ,
#        5.4       , 4.4       , 4.2       , 4.5       , 5.6       ,
#        3.9       , 4.1       , 3.6       , 4.7       , 4.3       ,
#        3.        , 4.6       , 3.8       , 2.8       , 2.6       ,
#        3.3       , 3.2       , 8.5       , 8.7       , 8.4       ,
#        2.2       , 2.9       , 2.7       , 1.8       , 2.3       ,
#        8.9       , 3.1       , 2.1       , 8.8       , 9.1       ,
# ...

# %%
amazon_p['imdb_votes'].unique()
# Out:
# array([ 1092., 89766., 63026., ...,  1526.,   929.,  1335.])

# %%
amazon_p['tmdb_popularity'].unique()
# Out:
# array([15.424,  8.647,  8.435, ...,  1.306,  0.91 ,  1.406])

# %%
amazon_p['tmdb_score'].unique()
# Out:
# array([ 7.6       ,  8.        ,  7.8       ,  7.4       ,  7.7       ,
#         8.3       ,  7.2       ,  3.6       ,  7.3       ,  4.1       ,
#         7.        ,  7.5       ,  6.9       ,  6.5       ,  7.1       ,
#         6.1       ,  6.3       ,  6.6       ,  5.6       ,  6.8       ,
#         6.4       ,  5.9       ,  5.        ,  6.7       ,  4.        ,
#         5.8       ,  5.1       ,  5.4       ,  6.        ,  5.99146391,
#         5.3       ,  5.5       ,  5.7       ,  4.6       ,  3.2       ,
#         3.3       ,  6.2       ,  4.2       ,  4.9       ,  5.2       ,
#         4.8       ,  4.4       ,  8.5       ,  3.5       ,  4.5       ,
#         3.        ,  2.6       ,  4.7       ,  4.3       ,  2.        ,
#         3.4       ,  3.7       ,  2.7       ,  3.8       ,  1.        ,
#         9.        ,  1.8       , 10.        ,  2.5       ,  7.9       ,
#         8.1       ,  8.2       ,  8.7       ,  3.9       ,  3.1       ,
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
amazon_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124179 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    124179 non-null  object
#  1   title                 124179 non-null  object
#  2   type                  124179 non-null  object
#  3   description           124179 non-null  object
#  4   release_year          124179 non-null  int64
#  5   age_certification     124179 non-null  object
#  6   runtime               124179 non-null  int64
#  7   genres                124179 non-null  object
#  8   production_countries  124179 non-null  object
#  9   seasons               124179 non-null  int64
#  10  imdb_id               124179 non-null  object
#  11  imdb_score            124179 non-null  float64
#  12  imdb_votes            124179 non-null  float64
#  13  tmdb_popularity       124179 non-null  float64
# ...

# %% [markdown]
# From this, it can be seen that `release_year` has int data type.
# It needs to be converted to Datetime

# %%
# Import Datetime
import datetime
from datetime import datetime

# %%
amazon_p['release_year'] = pd.to_datetime(amazon_p['release_year'], format = '%Y')  # no month and date provided, by default 01-01

# %%
amazon_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124179 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    124179 non-null  object
#  1   title                 124179 non-null  object
#  2   type                  124179 non-null  object
#  3   description           124179 non-null  object
#  4   release_year          124179 non-null  datetime64[ns]
#  5   age_certification     124179 non-null  object
#  6   runtime               124179 non-null  int64
#  7   genres                124179 non-null  object
#  8   production_countries  124179 non-null  object
#  9   seasons               124179 non-null  int64
#  10  imdb_id               124179 non-null  object
#  11  imdb_score            124179 non-null  float64
#  12  imdb_votes            124179 non-null  float64
#  13  tmdb_popularity       124179 non-null  float64
# ...

# %%
amazon_p['release_year'].head()
# Out:
# 0   1934-01-01
# 1   1934-01-01
# 2   1934-01-01
# 3   1926-01-01
# 4   1926-01-01
# Name: release_year, dtype: datetime64[ns]

# %%
amazon_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124179 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    124179 non-null  object
#  1   title                 124179 non-null  object
#  2   type                  124179 non-null  object
#  3   description           124179 non-null  object
#  4   release_year          124179 non-null  datetime64[ns]
#  5   age_certification     124179 non-null  object
#  6   runtime               124179 non-null  int64
#  7   genres                124179 non-null  object
#  8   production_countries  124179 non-null  object
#  9   seasons               124179 non-null  int64
#  10  imdb_id               124179 non-null  object
#  11  imdb_score            124179 non-null  float64
#  12  imdb_votes            124179 non-null  float64
#  13  tmdb_popularity       124179 non-null  float64
# ...

# %%
amazon_p['genres']
# Out:
# 0         ['comedy', 'family', 'animation', 'action', 'f...
# 1         ['comedy', 'family', 'animation', 'action', 'f...
# 2         ['comedy', 'family', 'animation', 'action', 'f...
# 3         ['action', 'drama', 'war', 'western', 'comedy'...
# 4         ['action', 'drama', 'war', 'western', 'comedy'...
#                                 ...
# 124342                                  ['family', 'drama']
# 124343                                  ['family', 'drama']
# 124344                                  ['family', 'drama']
# 124345                                  ['family', 'drama']
# 124346                                  ['family', 'drama']
# Name: genres, Length: 124179, dtype: object

# %%
amazon_p['genres'].unique()
# Out:
# array(["['comedy', 'family', 'animation', 'action', 'fantasy', 'horror']",
#        "['action', 'drama', 'war', 'western', 'comedy', 'european']",
#        "['romance', 'war', 'drama']", ...,
#        "['drama', 'romance', 'comedy', 'history']",
#        "['thriller', 'western', 'comedy']",
#        "['comedy', 'action', 'family']"], dtype=object)

# %% [markdown]
# It is observed that `genre` is NOT a real list yet — it’s a string that looks like a list. Hence `.explode()` will not work directly.

# %%
import ast  # abstract syntax tree

amazon_p['genres'] = amazon_p['genres'].apply(lambda x: ast.literal_eval(x))    # string to list

# %%
print(type(amazon_p['genres'].iloc[0]))
# Out:
# <class 'list'>

# %%
genres_exploded = amazon_p.explode('genres')  # each genre into separate row

# %%
genres_exploded['genres'].value_counts()
# Out:
# genres
# drama            69681
# comedy           41295
# thriller         33012
# action           30326
# romance          28570
# crime            20570
# horror           14106
# european         12527
# scifi            11404
# fantasy           8913
# family            8282
# western           8034
# history           6750
# documentation     6454
# music             6288
# war               5776
# animation         3754
# sport             3422
# reality            387
# Name: count, dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The following manipulations have been done:
# The following manipulations have been done:
#
# 1.   Data Cleaning
# 2.   Changing the datatypes of required columns
# 3.   Merging the datasets based on the common or primary key
# 4.   Removing duplicated data and filling null values based on the requirements to fill them with mean, median or custom details.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Average IMDb Score by Genre — Bar Chart

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate average rating per genre
avg_rating = (genres_exploded.groupby('genres')['imdb_score'].mean().sort_values(ascending=False).head(10).reset_index())

plt.figure(figsize=(8,6))
sns.barplot(data=avg_rating, x='genres', y='imdb_score', color = 'orange')

plt.title("Top 10 Genres by Average IMDb Score", fontsize=14)
plt.xlabel("Genre", fontsize=12)
plt.ylabel("Average IMDb Score", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart because:
# We are comparing categorical variable (genre) against a numerical aggregated metric (mean IMDb score)
#
# Barplot clearly shows magnitude difference

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some niche genres may have higher ratings.
#
# High-volume genres are not necessarily highest-rated.
#
# Quality and quantity are not directly proportional. Drama	had a value count of 69681(highest quantity) but it is still in the 7th place as per the visualisation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Creating content of the genre that has higher IMDb score is one of the ideas that Amazon can look into.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Dominance of content type - Donut Chart

# %%
import pandas as pd
import plotly.express as px

type_counts = amazon_p['type'].value_counts().reset_index()
type_counts.columns = ['Type', 'Count']

# Create pie chart
fig = px.pie(
    type_counts,
    names='Type',
    values='Count',
    title='Dominance of Content Types on Amazon Prime Video',
    color_discrete_sequence=px.colors.qualitative.Set3,
    hole=0.4
)

# Add data labels
fig.update_traces(textinfo='label+percent', textposition='inside')

# Add background color, shadow-like effect, and border-like feel
fig.update_layout(
    paper_bgcolor='#f9f9f9',  # Light gray background
    plot_bgcolor='#ffffff',   # White plot area (though not as relevant for pie charts)
    margin=dict(t=80, l=50, r=50, b=50),
    title=dict(
        x=0.5,
        xanchor='center',
        font=dict(size=20)
    ),
    font=dict(
        family='Arial',
        size=14,
        color='#333333'
    ),
    # Simulated border using padding (margins) and background
    annotations=[
        dict(
            text='',
            x=0.5,
            y=0.5,
            showarrow=False,
            font=dict(size=14),
            bordercolor='gray',
            borderwidth=2,
            borderpad=10,
            bgcolor='#ffffff',
            opacity=0.5
        )
    ]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Donut chart is perfect for visualizing proportions.
#
# It clearly shows the dominant content type (likely “Movie” or “TV Show”) and how much of the platform it occupies compared to the rest.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Dominance of a single content type: One type (likely Movie) makes up the majority of the content library. This indicates what Amazon Prime is primarily offering to its users.
#
# Smaller share for other types: If, say, TV Shows or Documentaries form only a small slice, it may point to underrepresented categories — a potential area for growth.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Content investment alignment: If movies dominate but Prime wants to compete with platforms like Netflix in the binge-watching space, they might consider increasing TV show production/acquisition.
#
# User targeting: If the platform knows its users are here mainly for movies, it can optimize the homepage and recommendations accordingly.
#
# Filling the gaps: If other types (e.g., Documentaries or Kids’ content) have small percentages, they can be opportunities to differentiate in niche markets.
#
# Any signs of potential negative growth?
#
# Lack of balance: A heavily skewed content mix might alienate viewers looking for variety, especially if they expect more TV shows or genre diversity.
#
# If the platform continues investing in the dominant category without improving others, it risks becoming one-dimensional, which could limit audience growth or retention over time.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Check the column names to verify actual IMDb score column
print(amazon_p.columns)

# Replace 'imdb_score' below if the column name is different
score_column = 'imdb_score'

# Filter for valid IMDb scores and a specific content type (e.g., 'MOVIE')
amazon_filtered = amazon_p[
    amazon_p[score_column].notnull() &
    (amazon_p['type'].str.upper() == 'MOVIE')
]

# Ensure release_year is numeric
amazon_filtered['release_year'] = pd.to_numeric(amazon_filtered['release_year'], errors='coerce')
amazon_filtered = amazon_filtered.dropna(subset=['release_year'])

# Group and calculate average IMDb score by year
ratings_by_year = amazon_filtered.groupby('release_year')[score_column].mean().reset_index()

# Plot
plt.figure(figsize=(10,8))
sns.lineplot(data=ratings_by_year, x='release_year', y=score_column, marker='o', color='teal')

# Add data labels
# for i in range(len(ratings_by_year)):
#     x = ratings_by_year['release_year'].iloc[i]
#     y = ratings_by_year[score_column].iloc[i]
#     plt.text(x, y + 0.02, f"{y:.1f}", ha='center', va='bottom', fontsize=9, color='black')

# Final touches
plt.title('Average IMDb Score by Year (Movies on Amazon Prime)', fontsize=16)
plt.xlabel('Release Year', fontsize=12)
plt.ylabel('Average IMDb Score', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score', 'person_id', 'name', 'character', 'role'],
#       dtype='object')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This line chart helps track trends over time, which is exactly what you're doing here — looking at how the average IMDb rating of movies on Amazon Prime changes across release years. It’s a simple but powerful way to spot patterns, dips, or improvements in movie quality over time.
#
# Also, filtering just for movies keeps the analysis focused, since shows often have different rating behaviors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The main Pointers:
#
# Fluctuating quality: IMDb scores don't follow a straight line — there are ups and downs across the years. This suggests that movie quality (as rated by audiences) has varied over time.
#
# Older movies often score higher: Earlier decades (e.g., 1960s–1980s) tend to show slightly higher average ratings, possibly due to the long-term popularity of classics that have stood the test of time.
#
# Recent decline: If the plot shows a dip in more recent years (especially post-2015), it might suggest a shift in audience preferences or that newer movies are being rated more critically.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact: Content sourcing decisions: If older movies consistently score higher, Amazon could spotlight these titles more on the platform — maybe in curated “Hidden Classics” sections.
#
# Production quality control: If newer content shows a decline in scores, the content team can investigate what's not resonating — perhaps writing, production value, or originality.
#
# Marketing leverage: High-scoring years or decades could be used for themed promotions (e.g., “Top-Rated Films from the 80s”).
#
# Any insight that signals negative growth? Yes, potentially:
#
# A decline in average scores for newer releases might indicate that recently acquired or produced content isn't meeting audience expectations. This could hurt viewer retention or brand trust if it continues unchecked.
#
# If Amazon relies too heavily on low-rated newer content just to fill the library, it could weaken overall engagement and satisfaction over time.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Horizontal Bar Plot
import pandas as pd
import plotly.express as px

# Filter and prepare top 10 unique titles by popularity
top_popular = (
    amazon_p[['title', 'tmdb_popularity', 'type']]  # Including 'type' for filtering
    .dropna(subset=['tmdb_popularity'])
    .drop_duplicates('title')
)

# Optional: Filter by type if desired (e.g., only movies)
top_popular = top_popular[top_popular['type'].str.upper() == 'MOVIE']

# Get top 10
top_popular = top_popular.sort_values(by='tmdb_popularity', ascending=False).head(10)

# Create horizontal bar chart
fig = px.bar(
    top_popular,
    x='tmdb_popularity',
    y='title',
    orientation='h',
    title='Top 10 Most Popular Movies (TMDB)',
    labels={'tmdb_popularity': 'Popularity', 'title': 'Title'},
    text='tmdb_popularity',  # Add data labels
    color_discrete_sequence=['#63b3ed']  # Optional: soft blue
)

# Layout customizations: background, border feel, shadows
fig.update_layout(
    yaxis={'categoryorder': 'total ascending'},
    plot_bgcolor='#ffffff',
    paper_bgcolor='#f8f9fa',
    font=dict(family='Arial', size=12, color='#333'),
    title=dict(
        font=dict(size=18),
        x=0.5,
        xanchor='center'
    ),
    margin=dict(t=80, l=100, r=40, b=40),
    bargap=0.3,
    hoverlabel=dict(bgcolor="white", font_size=12, font_family="Arial")
)

# Simulated border/shadow effect (simple)
fig.update_traces(
    texttemplate='%{text:.1f}',
    textposition='outside',
    marker=dict(
        line=dict(color='gray', width=0.8),  # Simulated border
        opacity=0.95
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# Filter: drop missing IMDb votes and remove duplicate titles
top_popular = (
    amazon_p[['title', 'imdb_votes']]
    .dropna(subset=['imdb_votes'])
    .drop_duplicates('title')
    .sort_values(by='imdb_votes', ascending=False)
    .head(10)
)

# Create horizontal bar chart with data labels
fig = px.bar(
    top_popular,
    x='imdb_votes',
    y='title',
    orientation='h',
    title='Top 10 Most Popular Titles (IMDb Votes)',
    labels={'imdb_votes': 'Votes', 'title': 'Title'},
    text='imdb_votes',
    color_discrete_sequence=['#1f77b4']
)

# Sort titles by total (ascending for horizontal bar)
fig.update_layout(
    yaxis={'categoryorder': 'total ascending'},
    plot_bgcolor='#f9f9f9',      # Light inner background
    paper_bgcolor='#ffffff',     # White outer background
    font=dict(family='Arial', size=12, color='#333'),
    title=dict(font=dict(size=18), x=0.5),
    margin=dict(t=80, l=120, r=40, b=40),
    bargap=0.3,
    hoverlabel=dict(bgcolor='white', font_size=12, font_family='Arial')
)

# Simulate borders and shadows, add data label formatting
fig.update_traces(
    texttemplate='%{text:.0f}',  # No decimal for votes
    textposition='outside',
    marker=dict(
        line=dict(color='gray', width=1),  # Simulated border
        opacity=0.95                       # Shadow-like effect
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Chose a dynamic horizontal bar chart with a dropdown, which is brilliant for comparison. It solves a common dashboard problem: too many charts cluttering up the space. With this dropdown, the viewer can toggle between two key popularity metrics — IMDb Votes and TMDB Popularity — without needing to look at two separate visuals.
#
# This makes it easier for stakeholders to spot differences between critical acclaim and real-time engagement

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By looking at the two views one after the other, we can uncover some subtle but important patterns:
#
# Different types of popularity:
#
# IMDb Votes show long-term engagement — users who cared enough to vote.
# TMDB Popularity is more about current buzz — page views, interactions, etc.
# There may be titles that rank high in one but not the other, which tells us a lot:
#
# A title with many IMDb votes but low TMDB popularity may be past its peak or a classic with lasting appeal.
# A title with high TMDB popularity but fewer IMDb votes might be newer or just going viral now.
# This comparison helps balance what’s popular now vs what has enduring value.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact: Content lifecycle planning: If a title is rising in TMDB popularity but not yet established on IMDb, it might be a good time to promote it or give it more visibility while buzz is high.
#
# Library strategy: Titles with high IMDb votes indicate long-term interest — useful for deciding which licenses to renew or extend.
#
# Audience segmentation: These two metrics might appeal to different viewer types (e.g., trend-watchers vs. critics), which can help tailor personalized recommendations.
#
# Any red flags? If only a few titles dominate both lists, it may indicate overreliance on a handful of hits — not ideal for a platform that wants a rich, diverse catalog.
#
# If many TMDB-popular titles don’t convert into high votes or good scores, there’s a risk of shallow engagement — viewers may click but not stick around.

# %% [markdown]
# #### Chart - 5

# %%
plt.figure(figsize=(8,5))
sns.histplot(amazon_p['imdb_score'], bins=20, kde=True)

plt.title("Distribution of IMDb Ratings (10 Bins)")
plt.xlabel("IMDb Score")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most titles are concentrated in the 5–7 rating range. Platform content is mostly average to moderately good.
#
# Right tail is thin. Limited premium or critically acclaimed content.
#
# Left tail is also thin. Platform avoids very poor-quality content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Content quality is stable and consistent. No extreme skewness or imbalance.
# Increasing high-rated (8+) content could:
#
# Improve brand perception
#
# Increase subscriptions
#
# Boost audience loyalty

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# To help Amazon Prime Video achieve its business objectives—such as increasing viewer engagement, retention, and market share—strategic insights from the data visuals can guide targeted actions.
#
# First, the **genre analysis** reveals an overconcentration in a few popular genres like Drama and Comedy. While these attract mass audiences, Amazon Prime should consider **diversifying content** by investing in underrepresented genres like Sci-Fi, Animation, and Documentary, especially for TV shows. This can help expand its user base into niche segments, such as families, educators, and young adults.
#
# Second, the **content type distribution** shows a strong dominance of movies. If Prime aims to compete with platforms like Netflix in binge-friendly content, it should **scale up high-quality series and original shows**, where user engagement is typically longer and stickier.
#
# Third, the **IMDb scores by year** indicate a slight decline or stagnation in recent content quality. Improving content curation and focusing on higher-rated productions could boost brand perception and reduce churn. Additionally, insights from the **IMDb votes vs. score chart** suggest that while some content gets high visibility, it doesn’t always correspond to high ratings. This calls for smarter promotion strategies—**pushing well-rated but lesser-known titles** could enhance viewer satisfaction.
#
# Finally, using **popularity metrics from IMDb and TMDB**, Amazon Prime can sharpen its recommendation algorithms and content strategy to highlight trending, top-rated, or hidden-gem titles based on both engagement and critical reception.
#
# In summary, by rebalancing content type, genre diversity, quality focus, and recommendation intelligence, Amazon Prime can drive sustainable growth and deeper viewer loyalty.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This EDA project aimed to uncover key insights from the Amazon Prime Video dataset to inform strategic business decisions related to content production, acquisition, and user engagement.
#
# Key Learnings:
#
# The analysis revealed that Amazon Prime’s content library is predominantly composed of movies, with comparatively fewer shows. Genre distribution showed a high concentration in Drama, Comedy, and Action across all content types. Insights from IMDb scores and votes indicated that while some highly visible titles gained significant audience traction, their quality—as measured by IMDb scores—did not always correlate positively. Temporal analysis of IMDb scores across years showed minimal improvement or decline, suggesting potential stagnation in content quality. Popularity metrics from TMDB and IMDb helped identify top-performing titles, indicating what genres and content types currently drive platform traffic.
#
# Challenges Faced:
#
# Several challenges arose during the project. The dataset required extensive cleaning due to missing values and non-standardized genre and production_countries entries. Many records had duplicate titles or inconsistencies in content classification (e.g., varied casing in 'type') like release_year. Parsing the genre and production_countries column, which contained comma-separated values, required preprocessing for frequency analysis. Logarithmic scaling was necessary for IMDb votes due to significant variance, which required careful visualization to preserve interpretability.
#
# Achievements:
#
# Despite the challenges, the project successfully built multiple visualizations using Plotly and Seaborn to illustrate genre popularity, IMDb score trends, and content type distribution. Interactive dashboards with dropdowns allowed for dynamic data exploration. The insights derived are directly actionable—for example, by identifying underutilized genres or highlighting mismatches between popularity and critical reception. These findings can support data-driven decision-making in content strategy, marketing, and product development on the platform.
#
# Overall, the project demonstrated effective use of Python-based data analysis and visualization tools to extract meaningful business intelligence from streaming platform data.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
